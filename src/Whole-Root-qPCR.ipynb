# %% [markdown]
# Plots for whole root 2uM est induction!
# log log plots for qPCR data rom MYB83_induced
#
# these are the log2 fold change values is this what we want here?

# %%
import numpy as np
import matplotlib.pyplot as plt
  

myb83 = [12.73,12.1,24.64,29.46,19.78,14.93]
irx15 = [0.642,0.667,0.582,0.516,0.462,0.212]
lac11 = [0.692,0.795,0.778,0.984,0.799,0.726]
cesa8 = [0.796,0.834,0.566,0.637,0.788,1.021]

lines = plt.plot(myb83,irx15)
## changes line width and color
plt.setp(lines, linewidth=2, color='m')
plt.xlabel('Myb83')
plt.ylabel('irx3')
plt.show()

# %% [markdown]
# Now lets make log-log plots for each of the MYB83 targets
# TODO: I should test myb46 and vnd7 feedback with my qpcr data!!!

# %%
## our figure has 2 rows and two coulmns this will be the first plot of the figure

plt.subplot(221)
lines = plt.plot(myb83,irx15)
## changes line width and color
plt.setp(lines, linewidth=2, color='m')
plt.xlabel('MYB83')
plt.ylabel('IRX3')
plt.title('IRX3 target')
plt.grid(True)

plt.subplot(222)
lines = plt.plot(myb83,lac11)
## changes line width and color
plt.setp(lines, linewidth=2, color='m')
plt.xlabel('MYB83')
plt.ylabel('LAC11')
plt.title('LAC11 target')
plt.grid(True)

plt.subplot(223)
lines = plt.plot(myb83,cesa8)
## changes line width and color
plt.setp(lines, linewidth=2, color='m')
plt.xlabel('MYB83')
plt.ylabel('CESA8')
plt.title('CESA8 target')
plt.grid(True)


plt.subplot(224)
lines = plt.plot(myb83,myb83)
## changes line width and color
plt.setp(lines, linewidth=2, color='m')
plt.xlabel('MYB83')
plt.ylabel('MYB83')
plt.title('MYB83')
plt.grid(True)

plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-3ac1fae61d14> in <module>()
#       2
#       3 plt.subplot(221)
# ----> 4 lines = plt.plot(myb83,irx15)
#       5 ## changes line width and color
#       6 plt.setp(lines, linewidth=2, color='m')
#
# NameError: name 'myb83' is not defined

# %% [markdown]
# think of each as a phenotype...
#
# add error bars to graphs
#
# kubo and siobhans data to repeat and double check
#
# test for feed back in network with my qPCR data...
#
# which is biologically most significant phenotype for grant..
#
#
# Not sure what this says lets check vnd7 should be more of a linear relationship
# TODO: figure out how to make these plots functions

# %%
import numpy as np
import matplotlib.pyplot as plt

vnd7 = [3.342,3.294,3.10,2.915,-1.287,-0.77]
irx15 = [0.65,1.098,0.99,0.99,-0.86,-0.74]
lac11 = [2.326,2.211,2.4,1.29,-2.33,-0.17]
cesa8 = [1.8,1.45,1.42,0.72,-0.51,-0.84]
myb83 = [1.89,1.75,1.8,0.215,0.03,0.03]
myb46 = [1.86,1.96,1.175,-0.094,-1.473,-0.54]

lines = plt.plot(myb83,irx15, 'ro')
## changes line width and color
plt.setp(lines, linewidth=2, color='m')
plt.xlabel('VND7')
plt.ylabel('irx3')

plt.show()

# %%
plt.subplot(231)
lines = plt.plot(vnd7,irx15)
## changes line width and color
plt.setp(lines, linewidth=2, color='m')
plt.xlabel('VND7')
plt.ylabel('IRX3')
plt.title('IRX3 target')
plt.grid(True)
plt.ylim(ymin=-3, ymax=4)

plt.subplot(232)
lines = plt.plot(vnd7,lac11)
## changes line width and color
plt.setp(lines, linewidth=2, color='m')
plt.xlabel('VND7')
plt.ylabel('LAC11')
plt.title('LAC11 target')
plt.grid(True)
plt.ylim(ymin=-3, ymax=4)

plt.subplot(233)
lines = plt.plot(vnd7,cesa8)
## changes line width and color
plt.setp(lines, linewidth=2, color='m')
plt.xlabel('VND7')
plt.ylabel('CESA8')
plt.title('CESA8 target')
plt.grid(True)
plt.ylim(ymin=-3, ymax=4)

plt.subplot(234)
lines = plt.plot(vnd7,vnd7)
## changes line width and color
plt.setp(lines, linewidth=2, color='m')
plt.xlabel('VND7')
plt.ylabel('VND7')
plt.title('VND7')
plt.grid(True)
plt.ylim(ymin=-3, ymax=4)

plt.subplot(235)
lines = plt.plot(vnd7,myb83)
## changes line width and color
plt.setp(lines, linewidth=2, color='m')
plt.xlabel('VND7')
plt.ylabel('MYB83')
plt.title('MYB83 target')
plt.grid(True)
plt.ylim(ymin=-3, ymax=4)

plt.subplot(236)
lines = plt.plot(vnd7,myb46)
## changes line width and color
plt.setp(lines, linewidth=2, color='m')
plt.xlabel('VND7')
plt.ylabel('MYB46')
plt.title('MYB46 target')
plt.grid(True)
plt.ylim(ymin=-3, ymax=4)


plt.show()

# %% [markdown]
# FFL is this tracking from above
# or are these dynamics more from feedback within the system

# %%
plt.subplot(231)
lines = plt.plot(vnd7,irx15, 'ro')
## changes line width and color
plt.setp(lines, linewidth=2, color='m')
plt.xlabel('VND7')
plt.ylabel('IRX3')
plt.title('IRX3 target')
plt.grid(True)
plt.ylim(ymin=-3, ymax=4)

plt.subplot(232)
lines = plt.plot(vnd7,lac11, 'ro')
## changes line width and color
plt.setp(lines, linewidth=2, color='m')
plt.xlabel('VND7')
plt.ylabel('LAC11')
plt.title('LAC11 target')
plt.grid(True)
plt.ylim(ymin=-3, ymax=4)

plt.subplot(233)
lines = plt.plot(vnd7,cesa8, 'ro')
## changes line width and color
plt.setp(lines, linewidth=2, color='m')
plt.xlabel('VND7')
plt.ylabel('CESA8')
plt.title('CESA8 target')
plt.grid(True)
plt.ylim(ymin=-3, ymax=4)

plt.subplot(234)
lines = plt.plot(vnd7,vnd7, 'ro')
## changes line width and color
plt.setp(lines, linewidth=2, color='m')
plt.xlabel('VND7')
plt.ylabel('VND7')
plt.title('VND7')
plt.grid(True)
plt.ylim(ymin=-3, ymax=4)

plt.subplot(235)
lines = plt.plot(vnd7,myb83, 'ro')
## changes line width and color
plt.setp(lines, linewidth=2, color='m')
plt.xlabel('VND7')
plt.ylabel('MYB83')
plt.title('MYB83 target')
plt.grid(True)
plt.ylim(ymin=-3, ymax=4)

plt.subplot(236)
lines = plt.plot(vnd7,myb46, 'ro')
## changes line width and color
plt.setp(lines, linewidth=2, color='m')
plt.xlabel('VND7')
plt.ylabel('MYB46')
plt.title('MYB46 target')
plt.grid(True)
plt.ylim(ymin=-3, ymax=4)


plt.show()

# %% [markdown]
# VND7 and extrdiol induction plot

# %%
vnd7 = [3.342,3.294,]
est = [20,1.098,0.99,0.99,-0.86,-0.74]
